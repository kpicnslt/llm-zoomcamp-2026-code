# %% [markdown]
# persistent_rag_ingest ni kopiyasi

# %%
from ingest import load_faq_data

documents = load_faq_data()
print(f'Загужено {len(documents)} документов')
# Out:
# Загужено 1349 документов

# %%
docs_llm = [doc for doc in documents if doc['course'] == 'llm-zoomcamp']
print(f'LLM Zoomcamp: {len(docs_llm)} документов')
# Out:
# LLM Zoomcamp: 84 документов

# %%
import time
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

for doc in docs_llm:
    index.add(doc)
    print(f'Добавлено: {doc["question"][:60]}...')
    time.sleep(0.5)

index.close()
print('Готово. Индекс сохранён в faq.db')
# Out:
# Добавлено: I just discovered the course. Can I still join?...
# Добавлено: Course: I have registered for the LLM Zoomcamp. When can I e...
# Добавлено: What is the video/zoom link to the stream for the “Office Ho...
# Добавлено: How should I start the course and follow the weekly workflow...
# Добавлено: Leaderboard: I am not on the leaderboard / how do I know whi...
# Добавлено: Certificate: Can I follow the course in a self-paced mode an...
# Добавлено: I missed the first homework - can I still get a certificate?...
# Добавлено: Homework: Why does the content keep changing?...
# Добавлено: When will the course be offered next?...
# Добавлено: Are there any lectures/videos? Where are they?...
# Добавлено: Where can I track the LLM Zoomcamp syllabus, deadlines, home...
# Добавлено: Are there live sessions or office hours for each module?...
# Добавлено: Can I use Bluesky for learning in public credits?...
# Добавлено: Where is the LLM Zoomcamp Telegram channel?...
# ...
